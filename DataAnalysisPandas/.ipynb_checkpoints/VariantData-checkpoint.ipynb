# %%
import pandas
df=pandas.read_csv("/home/ghost/Downloads/weather.data.csv")

# %%
df
# Out:
#         Unnamed: 0   data        date                 param        siteid
# 0                1   0.00  2003-01-01         Precipitation          ACRE
# 1                2   0.00  2003-01-02         Precipitation     AlbertLea
# 2                3  11.32  2003-01-03         Precipitation          Ames
# 3                4   0.00  2003-01-04         Precipitation        Antigo
# 4                5   3.04  2003-01-05         Precipitation      Appleton
# 5                6   0.49  2003-01-06         Precipitation     Arlington
# 6                7   0.00  2003-01-07         Precipitation     Bean&Beet
# 7                8   0.00  2003-01-08         Precipitation     Brookings
# 8                9   0.00  2003-01-09         Precipitation    Brownstown
# 9               10   0.00  2003-01-10         Precipitation      Columbia
# 10              11   0.00  2003-01-11         Precipitation     Crookston
# 11              12   0.00  2003-01-12         Precipitation        Dekalb
# ...

# %%
df.set_index("date")
# Out:
#             Unnamed: 0   data                 param        siteid
# date
# 2003-01-01           1   0.00         Precipitation          ACRE
# 2003-01-02           2   0.00         Precipitation     AlbertLea
# 2003-01-03           3  11.32         Precipitation          Ames
# 2003-01-04           4   0.00         Precipitation        Antigo
# 2003-01-05           5   3.04         Precipitation      Appleton
# 2003-01-06           6   0.49         Precipitation     Arlington
# 2003-01-07           7   0.00         Precipitation     Bean&Beet
# 2003-01-08           8   0.00         Precipitation     Brookings
# 2003-01-09           9   0.00         Precipitation    Brownstown
# 2003-01-10          10   0.00         Precipitation      Columbia
# 2003-01-11          11   0.00         Precipitation     Crookston
# 2003-01-12          12   0.00         Precipitation        Dekalb
# 2003-01-13          13   0.00         Precipitation  DixonSprings
# ...

# %%
df.shape
# Out:
# (655362, 5)

# %%
df1=pandas.read_json("/home/ghost/Downloads/supermarkets.json")
df1
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
df2=pandas.read_excel("/home/ghost/Downloads/grocerylists.xls",sheet_name=0)
df2
# Out:
#              The Ultimatest Grocery List Spreadsheet!  \
# 0                 Compliments of www.grocerylists.org
# 1                                                 NaN
# 2                                          FOODSTUFFS
# 3                                                 NaN
# 4                                    Fresh vegetables
# 5                                         · Asparagus
# 6                                          · Broccoli
# 7                                           · Carrots
# 8                                       · Cauliflower
# 9                                            · Celery
# 10                                             · Corn
# 11                                        · Cucumbers
# 12                                 · Lettuce / Greens
# 13                                        · Mushrooms
# 14                                           · Onions
# 15                                          · Peppers
# ...

# %%
#grab url
df3=pandas.read_csv("https://pythonhow.com/supermarkets.csv")
df3
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20
